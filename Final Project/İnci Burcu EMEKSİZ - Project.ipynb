# %% [markdown]
# ## İnci Burcu EMEKSİZ - Project

# %% [markdown]
# ### Read the diamonds.csv file and describe it.

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

# %%
df_diamond = pd.read_csv("diamonds.csv",sep=',',encoding= 'latin-1')

# %%
df_diamond.head()
# Out:
#    index  carat      cut color clarity  depth  table     x     y     z  \
# 0      1   0.23    Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1      2   0.21  Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2      3   0.23     Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3      4   0.29  Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4      5   0.31     Good     J     SI2   63.3   58.0  4.34  4.35  2.75
#
#       price
# 0  Very Low
# 1  Very Low
# 2  Very Low
# 3  Very Low
# 4  Very Low

# %%
df_diamond.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   index    53940 non-null  int64
#  1   carat    53940 non-null  float64
#  2   cut      53940 non-null  object
#  3   color    53940 non-null  object
#  4   clarity  53940 non-null  object
#  5   depth    53940 non-null  float64
#  6   table    53940 non-null  float64
#  7   x        53940 non-null  float64
#  8   y        53940 non-null  float64
#  9   z        53940 non-null  float64
#  10  price    53940 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 4.5+ MB

# %%
df_diamond.describe()
# Out:
#               index         carat         depth         table             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184      5.731157
# std    15571.281097      0.474011      1.432621      2.234491      1.121761
# min        1.000000      0.200000     43.000000     43.000000      0.000000
# 25%    13485.750000      0.400000     61.000000     56.000000      4.710000
# 50%    26970.500000      0.700000     61.800000     57.000000      5.700000
# 75%    40455.250000      1.040000     62.500000     59.000000      6.540000
# max    53940.000000      5.010000     79.000000     95.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# ### Make at least 4 different analysis on Exploratory Data Analysis section.

# %%
sns.countplot(x='price',data=df_diamond)
# Out:
# <AxesSubplot:xlabel='price', ylabel='count'>

# %%
df_diamond.plot.scatter(x = 'price', y = 'depth')
# Out:
# <AxesSubplot:xlabel='price', ylabel='depth'>

# %%
sns.displot(df_diamond[df_diamond.price == 'High'].depth)
sns.displot(df_diamond[df_diamond.price == 'Low'].depth,color="r")
sns.displot(df_diamond[df_diamond.price == 'Medium'].depth,color="g")
sns.displot(df_diamond[df_diamond.price == 'Very High'].depth,color="b")
sns.displot(df_diamond[df_diamond.price == 'Very Low'].depth)

# %%
sns.displot(df_diamond[df_diamond.price == 'High'].table)
sns.displot(df_diamond[df_diamond.price == 'Low'].table,color="g")
sns.displot(df_diamond[df_diamond.price == 'Medium'].table,color="b")
sns.displot(df_diamond[df_diamond.price == 'Very High'].table,color="r")
sns.displot(df_diamond[df_diamond.price == 'Very Low'].table)

# %%
sns.boxplot(data=df_diamond)
# Out:
# <AxesSubplot:>

# %%
df_diamond.hist()
# Out:
# array([[<AxesSubplot:title={'center':'index'}>,
#         <AxesSubplot:title={'center':'carat'}>,
#         <AxesSubplot:title={'center':'depth'}>],
#        [<AxesSubplot:title={'center':'table'}>,
#         <AxesSubplot:title={'center':'x'}>,
#         <AxesSubplot:title={'center':'y'}>],
#        [<AxesSubplot:title={'center':'z'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.pairplot(df_diamond,hue='price')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2894             try:
# -> 2895                 return self._engine.get_loc(casted_key)
#    2896             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'price'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-225-b2d38e36bedf> in <module>
# ...

# %% [markdown]
# ### Pre-process the dataset to get ready for ML application. (Check missing data and handle them, can we need to do scaling or feature extraction etc.)

# %%
#check missing data
df_diamond.isna().sum()
# Out:
# index      0
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# x          0
# y          0
# z          0
# price      0
# dtype: int64

# %%
# Check duplicate values 

df_diamond.duplicated(subset=None, keep='first')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 53935    False
# 53936    False
# 53937    False
# 53938    False
# 53939    False
# Length: 53940, dtype: bool

# %%
df_diamond.describe()
# Out:
#               index         carat         depth         table             x  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184      5.731157
# std    15571.281097      0.474011      1.432621      2.234491      1.121761
# min        1.000000      0.200000     43.000000     43.000000      0.000000
# 25%    13485.750000      0.400000     61.000000     56.000000      4.710000
# 50%    26970.500000      0.700000     61.800000     57.000000      5.700000
# 75%    40455.250000      1.040000     62.500000     59.000000      6.540000
# max    53940.000000      5.010000     79.000000     95.000000     10.740000
#
#                   y             z
# count  53940.000000  53940.000000
# mean       5.734526      3.538734
# std        1.142135      0.705699
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# ...

# %% [markdown]
# ### Korrelationen

# %%
corr = df_diamond.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot=True)
plt.show()

# %%
corr = df_diamond.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr,annot=True)
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df_diamond.duplicated().sum()
# Out:
# 0

# %%
df_diamond
# Out:
#        index  carat        cut color clarity  depth  table     x     y     z  \
# 0          1   0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1          2   0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2          3   0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3          4   0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4          5   0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...    ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935  53936   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936  53937   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937  53938   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938  53939   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939  53940   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
#           price
# 0      Very Low
# ...

# %%
df_diamond.drop("index",axis=1,inplace=True)

# %%
df_diamond
# Out:
#        carat        cut color clarity  depth  table     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
#           price
# 0      Very Low
# 1      Very Low
# 2      Very Low
# 3      Very Low
# 4      Very Low
# ...         ...
# ...

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
price_encoder=LabelEncoder()
df_diamond["label"]= price_encoder.fit_transform(df_diamond["price"])
df_diamond
# Out:
#        carat        cut color clarity  depth  table     x     y     z  \
# 0       0.23      Ideal     E     SI2   61.5   55.0  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0  5.83  5.87  3.64
#
#           price  label
# 0      Very Low      4
# 1      Very Low      4
# 2      Very Low      4
# 3      Very Low      4
# ...

# %%
df_diamond["label"].describe()
# Out:
# count    53940.000000
# mean         3.020171
# std          1.392602
# min          0.000000
# 25%          1.000000
# 50%          4.000000
# 75%          4.000000
# max          4.000000
# Name: label, dtype: float64

# %%
df_diamond["label"].value_counts()
# Out:
# 4    34663
# 1    11271
# 2     4109
# 0     2308
# 3     1589
# Name: label, dtype: int64

# %%
df_diamond
# Out:
#        carat        cut color clarity  depth  table  label  label_cut
# 0       0.23      Ideal     E     SI2   61.5   55.0      4          2
# 1       0.21    Premium     E     SI1   59.8   61.0      4          3
# 2       0.23       Good     E     VS1   56.9   65.0      4          1
# 3       0.29    Premium     I     VS2   62.4   58.0      4          3
# 4       0.31       Good     J     SI2   63.3   58.0      4          1
# ...      ...        ...   ...     ...    ...    ...    ...        ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0      4          2
# 53936   0.72       Good     D     SI1   63.1   55.0      4          1
# 53937   0.70  Very Good     D     SI1   62.8   60.0      4          4
# 53938   0.86    Premium     H     SI2   61.0   58.0      4          3
# 53939   0.75      Ideal     D     SI2   62.2   55.0      4          2
#
# [53940 rows x 8 columns]

# %%
price_encoder=LabelEncoder()
df_diamond["Label_cut"]= price_encoder.fit_transform(df_diamond["cut"])
df_diamond
# Out:
#        carat        cut color clarity  depth  table  label  label_cut  \
# 0       0.23      Ideal     E     SI2   61.5   55.0      4          2
# 1       0.21    Premium     E     SI1   59.8   61.0      4          3
# 2       0.23       Good     E     VS1   56.9   65.0      4          1
# 3       0.29    Premium     I     VS2   62.4   58.0      4          3
# 4       0.31       Good     J     SI2   63.3   58.0      4          1
# ...      ...        ...   ...     ...    ...    ...    ...        ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0      4          2
# 53936   0.72       Good     D     SI1   63.1   55.0      4          1
# 53937   0.70  Very Good     D     SI1   62.8   60.0      4          4
# 53938   0.86    Premium     H     SI2   61.0   58.0      4          3
# 53939   0.75      Ideal     D     SI2   62.2   55.0      4          2
#
#        Label_cut
# 0              2
# 1              3
# 2              1
# 3              3
# 4              1
# ...

# %%
df_diamond.drop("cut",axis=1,inplace=True)

# %%
price_encoder=LabelEncoder()
df_diamond["Label_color"]= price_encoder.fit_transform(df_diamond["color"])
df_diamond
# Out:
#        carat color clarity  depth  table  label  label_cut  Label_cut  \
# 0       0.23     E     SI2   61.5   55.0      4          2          2
# 1       0.21     E     SI1   59.8   61.0      4          3          3
# 2       0.23     E     VS1   56.9   65.0      4          1          1
# 3       0.29     I     VS2   62.4   58.0      4          3          3
# 4       0.31     J     SI2   63.3   58.0      4          1          1
# ...      ...   ...     ...    ...    ...    ...        ...        ...
# 53935   0.72     D     SI1   60.8   57.0      4          2          2
# 53936   0.72     D     SI1   63.1   55.0      4          1          1
# 53937   0.70     D     SI1   62.8   60.0      4          4          4
# 53938   0.86     H     SI2   61.0   58.0      4          3          3
# 53939   0.75     D     SI2   62.2   55.0      4          2          2
#
#        Label_color
# 0                1
# 1                1
# 2                1
# 3                5
# 4                6
# ...

# %%
df_diamond
# Out:
#        carat clarity  depth  table  label  label_cut  Label_cut  Label_color
# 0       0.23     SI2   61.5   55.0      4          2          2            1
# 1       0.21     SI1   59.8   61.0      4          3          3            1
# 2       0.23     VS1   56.9   65.0      4          1          1            1
# 3       0.29     VS2   62.4   58.0      4          3          3            5
# 4       0.31     SI2   63.3   58.0      4          1          1            6
# ...      ...     ...    ...    ...    ...        ...        ...          ...
# 53935   0.72     SI1   60.8   57.0      4          2          2            0
# 53936   0.72     SI1   63.1   55.0      4          1          1            0
# 53937   0.70     SI1   62.8   60.0      4          4          4            0
# 53938   0.86     SI2   61.0   58.0      4          3          3            4
# 53939   0.75     SI2   62.2   55.0      4          2          2            0
#
# [53940 rows x 8 columns]

# %%
price_encoder=LabelEncoder()
df_diamond["Label_clarity"]= price_encoder.fit_transform(df_diamond["clarity"])
df_diamond
# Out:
#        carat clarity  depth  table  label  label_cut  Label_cut  Label_color  \
# 0       0.23     SI2   61.5   55.0      4          2          2            1
# 1       0.21     SI1   59.8   61.0      4          3          3            1
# 2       0.23     VS1   56.9   65.0      4          1          1            1
# 3       0.29     VS2   62.4   58.0      4          3          3            5
# 4       0.31     SI2   63.3   58.0      4          1          1            6
# ...      ...     ...    ...    ...    ...        ...        ...          ...
# 53935   0.72     SI1   60.8   57.0      4          2          2            0
# 53936   0.72     SI1   63.1   55.0      4          1          1            0
# 53937   0.70     SI1   62.8   60.0      4          4          4            0
# 53938   0.86     SI2   61.0   58.0      4          3          3            4
# 53939   0.75     SI2   62.2   55.0      4          2          2            0
#
#        Label_clarity
# 0                  3
# ...

# %%
df_diamond.drop("clarity",axis=1,inplace=True)

# %%
df_diamond
# Out:
#        carat  depth  table  label  label_cut  Label_cut  Label_color  \
# 0       0.23   61.5   55.0      4          2          2            1
# 1       0.21   59.8   61.0      4          3          3            1
# 2       0.23   56.9   65.0      4          1          1            1
# 3       0.29   62.4   58.0      4          3          3            5
# 4       0.31   63.3   58.0      4          1          1            6
# ...      ...    ...    ...    ...        ...        ...          ...
# 53935   0.72   60.8   57.0      4          2          2            0
# 53936   0.72   63.1   55.0      4          1          1            0
# 53937   0.70   62.8   60.0      4          4          4            0
# 53938   0.86   61.0   58.0      4          3          3            4
# 53939   0.75   62.2   55.0      4          2          2            0
#
#        Label_clarity
# 0                  3
# 1                  2
# 2                  4
# 3                  5
# 4                  3
# ...

# %%
df_diamond.drop("label_cut",axis=1,inplace=True)

# %%
df_diamond
# Out:
#        carat  depth  table  label  Label_cut  Label_color  Label_clarity
# 0       0.23   61.5   55.0      4          2            1              3
# 1       0.21   59.8   61.0      4          3            1              2
# 2       0.23   56.9   65.0      4          1            1              4
# 3       0.29   62.4   58.0      4          3            5              5
# 4       0.31   63.3   58.0      4          1            6              3
# ...      ...    ...    ...    ...        ...          ...            ...
# 53935   0.72   60.8   57.0      4          2            0              2
# 53936   0.72   63.1   55.0      4          1            0              2
# 53937   0.70   62.8   60.0      4          4            0              2
# 53938   0.86   61.0   58.0      4          3            4              3
# 53939   0.75   62.2   55.0      4          2            0              3
#
# [53940 rows x 7 columns]

# %%
sns.barplot(data=df_diamond)
plt.show()

# %%
df_diamond.drop("carat",axis=1,inplace=True)

# %%
df_diamond
# Out:
#        depth  table  label  Label_cut  Label_color  Label_clarity
# 0       61.5   55.0      4          2            1              3
# 1       59.8   61.0      4          3            1              2
# 2       56.9   65.0      4          1            1              4
# 3       62.4   58.0      4          3            5              5
# 4       63.3   58.0      4          1            6              3
# ...      ...    ...    ...        ...          ...            ...
# 53935   60.8   57.0      4          2            0              2
# 53936   63.1   55.0      4          1            0              2
# 53937   62.8   60.0      4          4            0              2
# 53938   61.0   58.0      4          3            4              3
# 53939   62.2   55.0      4          2            0              3
#
# [53940 rows x 6 columns]

# %%
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing

# %%
scaler = StandardScaler()

# %%
standard = preprocessing.StandardScaler().fit(df_diamond[["depth","Label_cut","Label_color","Label_clarity","table"]])

# %%
df_standard= standard.transform(df_diamond[["depth","Label_cut","Label_color","Label_clarity","table"]])

# %%
X,y = df_diamond.iloc[: , :-1],df.iloc[: , -1]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

model_dt = DecisionTreeClassifier(max_depth=5, random_state=42)
model_dt.fit(X_train,y_train)
print("DT_Train score: ",model_dt.score(X_train,y_train))
print("DT_Test score: ",model_dt.score(X_test,y_test))
# Out:
# DT_Train score:  0.0006356268870173208
# DT_Test score:  0.0

# %%
train_scores, test_scores = list(), list()
values = [i for i in range(1, 5)]
for i in values:

    model = DecisionTreeClassifier(max_depth=i)

    model.fit(X_train, y_train)

    train_yhat = model.predict(X_train)
    train_acc = accuracy_score(y_train, train_yhat)
    train_scores.append(train_acc)

    test_yhat = model.predict(X_test)
    test_acc = accuracy_score(y_test, test_yhat)
    test_scores.append(test_acc)

    print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))

pyplot.plot(values, train_scores, '-o', label='Train')
pyplot.plot(values, test_scores, '-o', label='Test')
pyplot.legend()
pyplot.show()
# Out:
# >1, train: 0.000, test: 0.000
# >2, train: 0.000, test: 0.000
# >3, train: 0.000, test: 0.000
# >4, train: 0.000, test: 0.000
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-224-593a478353ea> in <module>
#      17     print('>%d, train: %.3f, test: %.3f' % (i, train_acc, test_acc))
#      18
# ---> 19 pyplot.plot(values, train_scores, '-o', label='Train')
#      20 pyplot.plot(values, test_scores, '-o', label='Test')
#      21 pyplot.legend()
#
# NameError: name 'pyplot' is not defined
